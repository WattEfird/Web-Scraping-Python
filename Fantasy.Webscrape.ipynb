# %% [markdown]
# Scraping one page

# %%
import pandas as pd
import numpy as np
url = 'https://www.pro-football-reference.com/years/2005/fantasy.htm'

df = pd.read_html(url)[0]

# %%
df.head()
# Out:
#   Unnamed: 0_level_0    Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Rk                Player                 Tm
# 0                  1     Shaun Alexander*+                SEA
# 1                  2        Larry Johnson*                KAN
# 2                  3  LaDainian Tomlinson*                SDG
# 3                  4         Tiki Barber*+                NYG
# 4                  5       Edgerrin James*                IND
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Games     Passing          ...  \
#              FantPos                Age     G  GS     Cmp Att Yds  ...
# 0                 RB                 28    16  16       0   0   0  ...
# 1                 RB                 26    16   9       0   0   0  ...
# 2                 RB                 26    16  16       3   4  47  ...
# 3                 RB                 30    16  16       0   1   0  ...
# 4                 RB                 27    15  15       0   0   0  ...
#
#   Scoring           Fantasy
# ...

# %%
df.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',      'Rk'),
#             ('Unnamed: 1_level_0',  'Player'),
#             ('Unnamed: 2_level_0',      'Tm'),
#             ('Unnamed: 3_level_0', 'FantPos'),
#             ('Unnamed: 4_level_0',     'Age'),
#             (             'Games',       'G'),
#             (             'Games',      'GS'),
#             (           'Passing',     'Cmp'),
#             (           'Passing',     'Att'),
#             (           'Passing',     'Yds'),
#             (           'Passing',      'TD'),
#             (           'Passing',     'Int'),
#             (           'Rushing',     'Att'),
#             (           'Rushing',     'Yds'),
#             (           'Rushing',     'Y/A'),
#             (           'Rushing',      'TD'),
#             (         'Receiving',     'Tgt'),
#             (         'Receiving',     'Rec'),
#             (         'Receiving',     'Yds'),
#             (         'Receiving',     'Y/R'),
# ...

# %%
data = df.copy()

# %%
df=df.droplevel(0, axis=1)

# %%
df.head()
# Out:
#   Rk                Player   Tm FantPos Age   G  GS Cmp Att Yds  ...  TD  2PM  \
# 0  1     Shaun Alexander*+  SEA      RB  28  16  16   0   0   0  ...  28  NaN
# 1  2        Larry Johnson*  KAN      RB  26  16   9   0   0   0  ...  21  NaN
# 2  3  LaDainian Tomlinson*  SDG      RB  26  16  16   3   4  47  ...  20  NaN
# 3  4         Tiki Barber*+  NYG      RB  30  16  16   0   1   0  ...  11    1
# 4  5       Edgerrin James*  IND      RB  27  15  15   0   0   0  ...  14  NaN
#
#    2PP FantPt    PPR   DKPt   FDPt  VBD PosRank OvRank
# 0  NaN    362  376.8  380.8  369.3  226       1      1
# 1  NaN    327  360.3  370.3  343.8  191       2      2
# 2  NaN    315  366.1  373.1  340.6  179       3      3
# 3  NaN    305  359.0  366.0  332.0  169       4      4
# 4  NaN    266  310.3  317.3  288.3  130       5      5
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 33 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rk       606 non-null    object
#  1   Player   606 non-null    object
#  2   Tm       606 non-null    object
#  3   FantPos  532 non-null    object
#  4   Age      606 non-null    object
#  5   G        606 non-null    object
#  6   GS       606 non-null    object
#  7   Cmp      606 non-null    object
#  8   Att      606 non-null    object
#  9   Yds      606 non-null    object
#  10  TD       606 non-null    object
#  11  Int      606 non-null    object
#  12  Att      606 non-null    object
#  13  Yds      606 non-null    object
#  14  Y/A      320 non-null    object
#  15  TD       606 non-null    object
#  16  Tgt      581 non-null    object
#  17  Rec      606 non-null    object
#  18  Yds      606 non-null    object
#  19  Y/R      440 non-null    object
# ...

# %%
df.shape
# Out:
# (606, 33)

# %%
df.head()
# Out:
#   Rk                Player   Tm FantPos Age   G  GS Cmp Att Yds  ...  TD  2PM  \
# 0  1     Shaun Alexander*+  SEA      RB  28  16  16   0   0   0  ...  28  NaN
# 1  2        Larry Johnson*  KAN      RB  26  16   9   0   0   0  ...  21  NaN
# 2  3  LaDainian Tomlinson*  SDG      RB  26  16  16   3   4  47  ...  20  NaN
# 3  4         Tiki Barber*+  NYG      RB  30  16  16   0   1   0  ...  11    1
# 4  5       Edgerrin James*  IND      RB  27  15  15   0   0   0  ...  14  NaN
#
#    2PP FantPt    PPR   DKPt   FDPt  VBD PosRank OvRank
# 0  NaN    362  376.8  380.8  369.3  226       1      1
# 1  NaN    327  360.3  370.3  343.8  191       2      2
# 2  NaN    315  366.1  373.1  340.6  179       3      3
# 3  NaN    305  359.0  366.0  332.0  169       4      4
# 4  NaN    266  310.3  317.3  288.3  130       5      5
#
# [5 rows x 33 columns]

# %%
df.iloc[60:62]
# Out:
#     Rk      Player   Tm  FantPos  Age   G  GS  Cmp  Att  Yds  ...  TD  2PM  \
# 60  Rk      Player   Tm  FantPos  Age   G  GS  Cmp  Att  Yds  ...  TD  2PM
# 61  60  Tatum Bell  DEN       RB   24  15   1    0    0    0  ...   8  NaN
#
#     2PP  FantPt    PPR   DKPt   FDPt  VBD  PosRank  OvRank
# 60  2PP  FantPt    PPR   DKPt   FDPt  VBD  PosRank  OvRank
# 61  NaN     149  166.5  173.5  157.5   13       21      60
#
# [2 rows x 33 columns]

# %%
df.iloc[120:122]
# Out:
#       Rk        Player   Tm FantPos Age   G  GS Cmp Att Yds  ... TD  2PM  2PP  \
# 120  118   Eric Parker  SDG      WR  26  15   9   0   0   0  ...  3  NaN  NaN
# 121  119  Bobby Engram  SEA      WR  32  13  13   0   0   0  ...  3  NaN  NaN
#
#     FantPt    PPR   DKPt   FDPt  VBD PosRank OvRank
# 120     94  151.0  155.0  122.5  NaN      39    NaN
# 121     92  158.8  163.8  125.3  NaN      40    NaN
#
# [2 rows x 33 columns]

# %%
df.iloc[90:]
# Out:
#       Rk            Player   Tm  FantPos  Age   G  GS  Cmp  Att   Yds  ...  \
# 90    89     Stephen Davis  CAR       RB   31  13  11    0    0     0  ...
# 91    Rk            Player   Tm  FantPos  Age   G  GS  Cmp  Att   Yds  ...
# 92    90       Marc Bulger  STL       QB   28   8   8  192  287  2297  ...
# 93    91       Kurt Warner  ARI       QB   34  10  10  242  375  2713  ...
# 94    92       Jamal Lewis  BAL       RB   26  15  15    0    0     0  ...
# ..   ...               ...  ...      ...  ...  ..  ..  ...  ...   ...  ...
# 601  583       Josh Scobey  SEA      NaN   26  16   0    0    0     0  ...
# 602  584    Reggie Swinton  ARI      NaN   30  15   0    0    0     0  ...
# 603  585     Aaron Rodgers  GNB       QB   22   3   0    9   16    65  ...
# 604  586       Fred McAfee  NOR      NaN   37  16   0    0    0     0  ...
# 605  587  Rasheed Marshall  SFO       WR   24  12   0    0    0     0  ...
#
#      TD  2PM  2PP  FantPt    PPR   DKPt   FDPt  VBD  PosRank  OvRank
# ...

# %%
df.isnull().sum()
# Out:
# Rk           0
# Player       0
# Tm           0
# FantPos     74
# Age          0
# G            0
# GS           0
# Cmp          0
# Att          0
# Yds          0
# TD           0
# Int          0
# Att          0
# Yds          0
# Y/A        286
# TD           0
# Tgt         25
# Rec          0
# Yds          0
# Y/R        166
# TD           0
# Fmb         49
# FL         403
# TD           0
# 2PM        563
# 2PP        571
# FantPt      82
# PPR         70
# DKPt        70
# FDPt        70
# VBD        513
# PosRank      0
# OvRank     509
# dtype: int64

# %%
pip install XlsxWriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import openpyxl

# %%
df2 = df.copy()
with pd.ExcelWriter('Fantasy_2005.xlsx') as writer:  
  df.to_excel(writer, sheet_name='Fantasy_2005_1')
